# %% [markdown]
# # First line

# %%
print("hello world")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print("hello world")
#
# TypeError: 'str' object is not callable

# %%
prinft = "ldkfjasdf"
print(prinft)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 prinft = ";ldkfj asdf"
# ----> 2 print(prinft)
#
# TypeError: 'str' object is not callable
