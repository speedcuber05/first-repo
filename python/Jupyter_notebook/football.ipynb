# %% [markdown]
# # importing the modules

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # setting up the file

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.width',750)


filepath=r"C:\Users\devan\OneDrive\Documents\programming\first-repo\male_players.csv"
data=pd.read_csv(filepath)

all_df=data.drop(columns=['url','Rank','Unnamed: 0.1', 'Unnamed: 0'])

# all_df is the base df we are going to use, I dropped all the useless columns, rank will be added later
# as the index

# %% [markdown]
# ### setting up goalkeeper data

# %%
gk_raw_df=all_df[all_df["Position"]=="GK"]
gk_df=gk_raw_df[['Name','OVR','GK Diving' , 'GK Handling' , 'GK Kicking' , 'GK Positioning','GK Reflexes',
                 'Weak foot','Skill moves','Preferred foot','Height','Weight','Age','Nation','League',
                 'Team','play style']].copy()

gk_df.index=np.arange(1,len(gk_df)+1)
gk_df.index.name = "Rank"

print(gk_df.head())
# Out:
#                        Name  OVR  GK Diving  GK Handling  GK Kicking  GK Positioning  GK Reflexes  Weak foot  Skill moves Preferred foot        Height        Weight  Age   Nation              League             Team                                   play style
# Rank
# 1      Gianluigi Donnarumma   89       90.0         84.0        73.0            87.0         90.0          3            1          Right  196cm / 6'5"  90kg / 198lb   25    Italy  Ligue 1 McDonald's         Paris SG                         Deflector+, Footwork
# 2                   Alisson   89       86.0         85.0        85.0            90.0         89.0          3            1          Right  193cm / 6'4"  91kg / 201lb   31   Brazil      Premier League        Liverpool        Deflector+, 1v1 Close Down, Far Throw
# 3          Thibaut Courtois   89       85.0         89.0        76.0            88.0         90.0          3            1           Left  200cm / 6'7"  96kg / 212lb   32  Belgium    LALIGA EA SPORTS      Real Madrid    1v1 Close Down+, Cross Claimer, Far Throw
# 4     Marc-André ter Stegen   89       86.0         85.0        89.0            86.0         91.0          4            1          Right  187cm / 6'2"  85kg / 187lb   32  Germany    LALIGA EA SPORTS     FC Barcelona                    Footwork+, 1v1 Close Down
# 5                   Ederson   88       87.0         82.0        91.0            86.0         87.0          3            1           Left  188cm / 6'2"  86kg / 190lb   31   Brazil      Premier League  Manchester City  Long Ball Pass+, Cross Claimer, Pinged Pass

# %% [markdown]
# ### setting up outfield data

# %%
outfield_raw_df=all_df[all_df['Position']!="GK"]
outfield_df=outfield_raw_df.drop(columns=['GK Diving' , 'GK Handling' , 'GK Kicking' , 'GK Positioning','GK Reflexes']).copy()

outfield_df.index=np.arange(1,len(outfield_df)+1)
outfield_df.index.name = "Rank"
print(outfield_df)
# Out:
#                   Name  OVR  PAC  SHO  PAS  DRI  DEF  PHY  Acceleration  Sprint Speed  Positioning  Finishing  Shot Power  Long Shots  Volleys  Penalties  Vision  Crossing  Free Kick Accuracy  Short Passing  Long Passing  Curve  Dribbling  Agility  Balance  Reactions  Ball Control  Composure  Interceptions  Heading Accuracy  Def Awareness  Standing Tackle  Sliding Tackle  Jumping  Stamina  Strength  Aggression Position  Weak foot  Skill moves Preferred foot         Height        Weight Alternative positions  Age          Nation            League             Team                                         play style
# Rank
# 1        Kylian Mbappé   91   97   90   80   92   36   78            97            97           93         94          90          83       84         84      83        78                  69             86            71     80         93       93       82         93            92         88             38                73             26               34              32       88       88        77          64       ST          4            5          Right   182cm / 6'0"  75kg / 165lb                    LW   25          France  LALIGA EA SPORTS      Real Madrid  Quick Step+, Acrobatic, Finesse Shot, Flair, R...
# 2                Rodri   91   66   80   86   84   87   85            65            66           76         74          92          89       71         62      84        76                  64             93            91     86         84       66       67         93            90         94             84                81             92               87              82       83       91        83          85      CDM          4            3          Right   191cm / 6'3"  82kg / 181lb                    CM   28           Spain    Premier League  Manchester City  Tiki Taka+, Aerial, Bruiser, Long Ball Pass, P...
# 3       Erling Haaland   91   88   92   70   81   45   88            80            94           96         96          94          83       90         90      74        58                  62             77            66     77         79       77       69         94            83         87             43                83             38               47              29       92       76        93          88       ST          3            3           Left   195cm / 6'5"  94kg / 207lb                   NaN   24          Norway    Premier League  Manchester City  Acrobatic+, Bruiser, Power Header, Power Shot,...
# 4      Jude Bellingham   90   80   87   83   88   78   83            81            80           91         90          85          86       77         74      90        66                  68             89            89     73         89       82       79         91            89         87             82                75             77               79              77       84       93        77          85      CAM          4            4          Right   186cm / 6'1"  75kg / 165lb                    CM   21         England  LALIGA EA SPORTS      Real Madrid  Relentless+, Flair, Intercept, Slide Tackle, T...
# 5             Vini Jr.   90   95   84   81   91   29   69            95            95           87         89          81          83       73         71      85        81                  62             83            77     79         93       94       84         86            90         83             26                50             32               25              18       74       84        65          58       LW          4            5          Right   176cm / 5'9"  73kg / 161lb                ST, LM   24          Brazil  LALIGA EA SPORTS      Real Madrid  Quick Step+, Chip Shot, Finesse Shot, First To...
# ...                ...  ...  ...  ...  ...  ...  ...  ...           ...           ...          ...        ...         ...         ...      ...        ...     ...       ...                 ...            ...           ...    ...        ...      ...      ...        ...           ...        ...            ...               ...            ...              ...             ...      ...      ...       ...         ...      ...        ...          ...            ...            ...           ...                   ...  ...             ...               ...              ...                                                ...
# 14341     Engson Singh   47   31   45   47   52   34   45            32            31           39         44          48          50       25         43      55        38                  44             45            51     46         51       64       68         32            50         53             23                37             33               39              40       27       65        36          47      CAM          3            2          Right   169cm / 5'7"  62kg / 137lb                    CM   21           India               ISL   Mohun Bagan SG                                                NaN
# 14342    Ousmane Sylla   47   67   38   46   45   40   55            66            67           47         34          50          33       32         40      43        35                  39             54            56     30         41       59       71         46            42         36             37                47             36               41              47       49       56        53          59       CM          3            2          Right   176cm / 5'9"  74kg / 163lb                   NaN   23         Senegal               MLS   Houston Dynamo                                                NaN
# 14343         Wei Feng   47   57   47   38   50   43   49            55            59           50         47          44          50       32         51      45        38                  29             37            33     36         49       60       66         48            48         46             41                50             43               42              42       53       51        57          24       RB          3            2          Right  181cm / 5'11"  69kg / 152lb                   NaN   22        China PR               CSL  Changchun Yatai                                                NaN
# 14344       Won Hui Do   47   66   35   46   46   41   64            69            63           45         24          52          39       33         42      41        39                  39             52            55     33         45       54       59         46            43         39             42                49             34               42              49       60       65        68          54       CM          3            2          Right   187cm / 6'2"  71kg / 157lb                   NaN   19  Korea Republic        K League 1      Jeju United                                                NaN
# 14345        Wu Yuhang   47   56   34   43   45   43   54            51            60           37         31          40          32       26         41      35        35                  34             51            50     32         43       57       60         45            42         39             43                42             40               45              51       42       49        57          56      CDM          3            2          Right   182cm / 6'0"  75kg / 165lb                   NaN   23        China PR               CSL     Zhejiang Pro                                                NaN
#
# [14345 rows x 49 columns]

# %% [markdown]
# # adding some new columns

# %%
# adding a column which adds all the stats of the goalkeeper
Stat_Sum= gk_df["GK Diving"] + gk_df["GK Handling"] + gk_df["GK Kicking"] + gk_df["GK Positioning"] + gk_df["GK Reflexes"]

col_position=gk_df.columns.get_loc("GK Reflexes") + 1
gk_df.insert(col_position,"Stat Sum",Stat_Sum)

print(gk_df)
# Out:
#                        Name  OVR  GK Diving  GK Handling  GK Kicking  GK Positioning  GK Reflexes  Stat Sum  Weak foot  Skill moves Preferred foot         Height        Weight  Age          Nation              League                Team                                   play style
# Rank
# 1      Gianluigi Donnarumma   89       90.0         84.0        73.0            87.0         90.0     424.0          3            1          Right   196cm / 6'5"  90kg / 198lb   25           Italy  Ligue 1 McDonald's            Paris SG                         Deflector+, Footwork
# 2                   Alisson   89       86.0         85.0        85.0            90.0         89.0     435.0          3            1          Right   193cm / 6'4"  91kg / 201lb   31          Brazil      Premier League           Liverpool        Deflector+, 1v1 Close Down, Far Throw
# 3          Thibaut Courtois   89       85.0         89.0        76.0            88.0         90.0     428.0          3            1           Left   200cm / 6'7"  96kg / 212lb   32         Belgium    LALIGA EA SPORTS         Real Madrid    1v1 Close Down+, Cross Claimer, Far Throw
# 4     Marc-André ter Stegen   89       86.0         85.0        89.0            86.0         91.0     437.0          4            1          Right   187cm / 6'2"  85kg / 187lb   32         Germany    LALIGA EA SPORTS        FC Barcelona                    Footwork+, 1v1 Close Down
# 5                   Ederson   88       87.0         82.0        91.0            86.0         87.0     433.0          3            1           Left   188cm / 6'2"  86kg / 190lb   31          Brazil      Premier League     Manchester City  Long Ball Pass+, Cross Claimer, Pinged Pass
# ...                     ...  ...        ...          ...         ...             ...          ...       ...        ...          ...            ...            ...           ...  ...             ...                 ...                 ...                                          ...
# 1812            Lim Jun Sub   48       45.0         51.0        52.0            46.0         52.0     246.0          2            1          Right   195cm / 6'5"  84kg / 185lb   21  Korea Republic          K League 1         Jeju United                                          NaN
# 1813             Alex Rando   48       47.0         47.0        51.0            52.0         46.0     243.0          2            1          Right   193cm / 6'4"  81kg / 179lb   24   United States                 MLS    New York City FC                                          NaN
# 1814           Roh Hee Dong   48       48.0         50.0        53.0            43.0         50.0     244.0          3            1          Right   192cm / 6'4"  88kg / 194lb   22  Korea Republic          K League 1          GwangJu FC                                          NaN
# 1815       Alexander Turkin   48       55.0         45.0        53.0            46.0         49.0     248.0          3            1          Right  180cm / 5'11"  65kg / 143lb   17         Austria       Ö. Bundesliga  Austria Klagenfurt                                          NaN
# 1816          Zhou Zhengkai   48       56.0         49.0        49.0            42.0         46.0     242.0          3            1          Right   183cm / 6'0"  72kg / 159lb   23        China PR                 CSL    Shanghai Shenhua                                          NaN
#
# [1816 rows x 18 columns]

# %%
# adding a column which will count the number of playstyles a player has, and set the height to an integer in cms
def count_playStyles(df):
    count_ps=np.empty(len(df))
    index=0
    for ps in df['play style']:
        if pd.notna(ps):
            count_ps[index]=len(ps.split(','))
        else:
            count_ps[index]=0
        index+=1
    return count_ps

def get_height(df):
    hts=np.empty(len(df))
    index=0
    for ht in df["Height"]:
        hts[index]=int(ht[0]+ht[1]+ht[2])
        index+=1
    return hts

gk_df["Height"]=get_height(gk_df)
gk_df["no. of play style"]= count_playStyles(gk_df)
gk_df["Total Stats"]= gk_df['Stat Sum'] + gk_df['Height'] + gk_df['no. of play style']
gk_df['Height'] = gk_df['Height'].astype(int)

gk_df
# Out:
#                        Name  OVR  GK Diving  GK Handling  GK Kicking  GK Positioning  GK Reflexes  Stat Sum  Weak foot  Skill moves Preferred foot  Height        Weight  Age          Nation              League                Team                                   play style  no. of play style  Total Stats
# Rank
# 1      Gianluigi Donnarumma   89       90.0         84.0        73.0            87.0         90.0     424.0          3            1          Right     196  90kg / 198lb   25           Italy  Ligue 1 McDonald's            Paris SG                         Deflector+, Footwork                2.0        622.0
# 2                   Alisson   89       86.0         85.0        85.0            90.0         89.0     435.0          3            1          Right     193  91kg / 201lb   31          Brazil      Premier League           Liverpool        Deflector+, 1v1 Close Down, Far Throw                3.0        631.0
# 3          Thibaut Courtois   89       85.0         89.0        76.0            88.0         90.0     428.0          3            1           Left     200  96kg / 212lb   32         Belgium    LALIGA EA SPORTS         Real Madrid    1v1 Close Down+, Cross Claimer, Far Throw                3.0        631.0
# 4     Marc-André ter Stegen   89       86.0         85.0        89.0            86.0         91.0     437.0          4            1          Right     187  85kg / 187lb   32         Germany    LALIGA EA SPORTS        FC Barcelona                    Footwork+, 1v1 Close Down                2.0        626.0
# 5                   Ederson   88       87.0         82.0        91.0            86.0         87.0     433.0          3            1           Left     188  86kg / 190lb   31          Brazil      Premier League     Manchester City  Long Ball Pass+, Cross Claimer, Pinged Pass                3.0        624.0
# ...                     ...  ...        ...          ...         ...             ...          ...       ...        ...          ...            ...     ...           ...  ...             ...                 ...                 ...                                          ...                ...          ...
# 1812            Lim Jun Sub   48       45.0         51.0        52.0            46.0         52.0     246.0          2            1          Right     195  84kg / 185lb   21  Korea Republic          K League 1         Jeju United                                          NaN                0.0        441.0
# 1813             Alex Rando   48       47.0         47.0        51.0            52.0         46.0     243.0          2            1          Right     193  81kg / 179lb   24   United States                 MLS    New York City FC                                          NaN                0.0        436.0
# 1814           Roh Hee Dong   48       48.0         50.0        53.0            43.0         50.0     244.0          3            1          Right     192  88kg / 194lb   22  Korea Republic          K League 1          GwangJu FC                                          NaN                0.0        436.0
# 1815       Alexander Turkin   48       55.0         45.0        53.0            46.0         49.0     248.0          3            1          Right     180  65kg / 143lb   17         Austria       Ö. Bundesliga  Austria Klagenfurt                                          NaN                0.0        428.0
# 1816          Zhou Zhengkai   48       56.0         49.0        49.0            42.0         46.0     242.0          3            1          Right     183  72kg / 159lb   23        China PR                 CSL    Shanghai Shenhua                                          NaN                0.0        425.0
#
# [1816 rows x 20 columns]

# %%
# doing the same for outfield players too
outfield_df["Height"]=get_height(outfield_df)
outfield_df["no. of play style"]= count_playStyles(outfield_df)

print(outfield_df)
# Out:
#                   Name  OVR  PAC  SHO  PAS  DRI  DEF  PHY  Acceleration  Sprint Speed  Positioning  Finishing  Shot Power  Long Shots  Volleys  Penalties  Vision  Crossing  Free Kick Accuracy  Short Passing  Long Passing  Curve  Dribbling  Agility  Balance  Reactions  Ball Control  Composure  Interceptions  Heading Accuracy  Def Awareness  Standing Tackle  Sliding Tackle  Jumping  Stamina  Strength  Aggression Position  Weak foot  Skill moves Preferred foot  Height        Weight Alternative positions  Age          Nation            League             Team                                         play style  no. of play style
# Rank
# 1        Kylian Mbappé   91   97   90   80   92   36   78            97            97           93         94          90          83       84         84      83        78                  69             86            71     80         93       93       82         93            92         88             38                73             26               34              32       88       88        77          64       ST          4            5          Right   182.0  75kg / 165lb                    LW   25          France  LALIGA EA SPORTS      Real Madrid  Quick Step+, Acrobatic, Finesse Shot, Flair, R...                6.0
# 2                Rodri   91   66   80   86   84   87   85            65            66           76         74          92          89       71         62      84        76                  64             93            91     86         84       66       67         93            90         94             84                81             92               87              82       83       91        83          85      CDM          4            3          Right   191.0  82kg / 181lb                    CM   28           Spain    Premier League  Manchester City  Tiki Taka+, Aerial, Bruiser, Long Ball Pass, P...                6.0
# 3       Erling Haaland   91   88   92   70   81   45   88            80            94           96         96          94          83       90         90      74        58                  62             77            66     77         79       77       69         94            83         87             43                83             38               47              29       92       76        93          88       ST          3            3           Left   195.0  94kg / 207lb                   NaN   24          Norway    Premier League  Manchester City  Acrobatic+, Bruiser, Power Header, Power Shot,...                5.0
# 4      Jude Bellingham   90   80   87   83   88   78   83            81            80           91         90          85          86       77         74      90        66                  68             89            89     73         89       82       79         91            89         87             82                75             77               79              77       84       93        77          85      CAM          4            4          Right   186.0  75kg / 165lb                    CM   21         England  LALIGA EA SPORTS      Real Madrid  Relentless+, Flair, Intercept, Slide Tackle, T...                5.0
# 5             Vini Jr.   90   95   84   81   91   29   69            95            95           87         89          81          83       73         71      85        81                  62             83            77     79         93       94       84         86            90         83             26                50             32               25              18       74       84        65          58       LW          4            5          Right   176.0  73kg / 161lb                ST, LM   24          Brazil  LALIGA EA SPORTS      Real Madrid  Quick Step+, Chip Shot, Finesse Shot, First To...                7.0
# ...                ...  ...  ...  ...  ...  ...  ...  ...           ...           ...          ...        ...         ...         ...      ...        ...     ...       ...                 ...            ...           ...    ...        ...      ...      ...        ...           ...        ...            ...               ...            ...              ...             ...      ...      ...       ...         ...      ...        ...          ...            ...     ...           ...                   ...  ...             ...               ...              ...                                                ...                ...
# 14341     Engson Singh   47   31   45   47   52   34   45            32            31           39         44          48          50       25         43      55        38                  44             45            51     46         51       64       68         32            50         53             23                37             33               39              40       27       65        36          47      CAM          3            2          Right   169.0  62kg / 137lb                    CM   21           India               ISL   Mohun Bagan SG                                                NaN                0.0
# 14342    Ousmane Sylla   47   67   38   46   45   40   55            66            67           47         34          50          33       32         40      43        35                  39             54            56     30         41       59       71         46            42         36             37                47             36               41              47       49       56        53          59       CM          3            2          Right   176.0  74kg / 163lb                   NaN   23         Senegal               MLS   Houston Dynamo                                                NaN                0.0
# 14343         Wei Feng   47   57   47   38   50   43   49            55            59           50         47          44          50       32         51      45        38                  29             37            33     36         49       60       66         48            48         46             41                50             43               42              42       53       51        57          24       RB          3            2          Right   181.0  69kg / 152lb                   NaN   22        China PR               CSL  Changchun Yatai                                                NaN                0.0
# 14344       Won Hui Do   47   66   35   46   46   41   64            69            63           45         24          52          39       33         42      41        39                  39             52            55     33         45       54       59         46            43         39             42                49             34               42              49       60       65        68          54       CM          3            2          Right   187.0  71kg / 157lb                   NaN   19  Korea Republic        K League 1      Jeju United                                                NaN                0.0
# 14345        Wu Yuhang   47   56   34   43   45   43   54            51            60           37         31          40          32       26         41      35        35                  34             51            50     32         43       57       60         45            42         39             43                42             40               45              51       42       49        57          56      CDM          3            2          Right   182.0  75kg / 165lb                   NaN   23        China PR               CSL     Zhejiang Pro                                                NaN                0.0
#
# [14345 rows x 50 columns]

# %% [markdown]
# ### normalizing free kicks from 0 - 1

# %%
def normalization(column):
    outfield_df[f"{column} normalized"]=(outfield_df[column] - outfield_df[column].min())/(outfield_df[column].max()-outfield_df[column].min())
normalization("Free Kick Accuracy")

# %% [markdown]
# # checking if the ovr ratings are the averages of their respective stats

# %%
mismatch_pac=(outfield_df['PAC'] - outfield_df['Acceleration']/2 - outfield_df['Sprint Speed']/2)
mismatch_pac=mismatch_pac[mismatch_pac.abs()>0.5]
result = pd.DataFrame({
    'Name': outfield_df.loc[mismatch_pac.index, 'Name'],
    'PAC': outfield_df.loc[mismatch_pac.index, 'PAC'],
    'PAC_mismatch': mismatch_pac
})
print(result.shape)
# Out:
# (782, 3)

# %% [markdown]
# # sorting data with groupby

# %%
# checking the highest avg stamina by the position
position_df=all_df.groupby('Position')
avg_sta_position=position_df["Stamina"].mean().sort_values(ascending=False)
print(avg_sta_position)
# Out:
# Position
# CDM    72.454887
# RB     71.866511
# CM     71.325926
# LB     71.014003
# RM     66.678571
# LM     65.671488
# CB     65.476744
# ST     65.097114
# CAM    64.997919
# LW     64.193548
# RW     64.176471
# GK     28.337004
# Name: Stamina, dtype: float64

# %%
# checking the best nation by the avg ovr

filter_all_df=all_df[all_df['OVR']>73]
nation_df=filter_all_df.groupby('Nation')
avg_ovr_nation=nation_df['OVR'] \
.agg(['mean','count']) \
.query('count > 11') 
avg_ovr_nation['mean'] = avg_ovr_nation['mean'].round().astype(int)
print(avg_ovr_nation.sort_values(by=['mean','count'],ascending=False))
# Out:
#                 mean  count
# Nation
# France            78    162
# England           78    152
# Germany           78    128
# Brazil            78    116
# Italy             78    113
# Holland           78     89
# Portugal          78     88
# Switzerland       78     31
# Uruguay           78     31
# Serbia            78     27
# Norway            78     17
# Spain             77    244
# Argentina         77    129
# Belgium           77     55
# Denmark           77     41
# Austria           77     33
# Croatia           77     33
# Morocco           77     28
# Turkey            77     26
# Ukraine           77     26
# Côte d'Ivoire     77     25
# Poland            77     21
# Senegal           77     21
# Japan             77     20
# Scotland          77     19
# Sweden            77     19
# Algeria           77     16
# Slovakia          77     12
# Colombia          76     35
# Nigeria           76     31
# United States     76     21
# Ghana             76     18
# Greece            76     16
# Ecuador           76     12
# Czech Republic    75     30
# Albania           75     12
